# %%
import cv2
import sys
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_dir = '/mnt/disks/user/project/Dataset/'

#data structure
#final_dir is the final structure as suggested in the thesis

final_dir = [os.path.join(base_dir,'FaceSwap/'),
             os.path.join(base_dir,'Reenactment/'),
             os.path.join(base_dir,'original/')]
print(final_dir)
# Out:
# ['/mnt/disks/user/project/Dataset/FaceSwap/', '/mnt/disks/user/project/Dataset/Reenactment/', '/mnt/disks/user/project/Dataset/original/']

# %%
videos = pd.DataFrame(columns=['vid_path','fps','frame_count',
                               'duration','height','width',
                               'format','faces','gender',
                               'age','manipulation_type'])

# %%
def append_dataframe(videopath):
    fps,frame_count,duration,height,width,face = 0,0,0,0,0,0
    vid_format,gender, manipulation_type = '','',''
    vidObj = cv2.VideoCapture(videopath)
    fps = vidObj.get(cv2.CAP_PROP_FPS)     # OpenCV2 version 2 used "CV_CAP_PROP_FPS"
    frame_count = int(vidObj.get(cv2.CAP_PROP_FRAME_COUNT))
    if (fps != 0) or (frame_count != 0):
        duration = frame_count/fps
    else:
        duration = 0
    height = vidObj.get(cv2.CAP_PROP_FRAME_HEIGHT) 
    width = vidObj.get(cv2.CAP_PROP_FRAME_WIDTH)
    vid_format = videopath.split('.')[1]
    manipulation = videopath.split('/')[-3]
    face,age_val,gender = object_detection(vidObj)
    global videos
    videos = videos.append({'vid_path' : videopath,
                            'fps' : fps,
                            'frame_count': frame_count,
                            'duration': duration,
                            'height': height,
                            'width': width,
                            'format':vid_format,
                            'faces':face,
                            'gender': gender,
                            'age': age_val,
                            'manipulation_type': manipulation
                           }, ignore_index = True)

# %%
def object_detection(vidObj):
    #load models
    age_net = cv2.dnn.readNetFromCaffe('/mnt/disks/user/project/deploy_age.prototxt', '/mnt/disks/user/project/age_net.caffemodel')
    gender_net = cv2.dnn.readNetFromCaffe('/mnt/disks/user/project/deploy_gender.prototxt', '/mnt/disks/user/project/gender_net.caffemodel')
    
    #relevant lists
    age_list = ['(0, 2)', '(4, 6)', '(8, 12)', '(15, 20)', '(25, 32)', '(38, 43)', '(48, 53)', '(60, 100)']
    gender_list = ['Male', 'Female']
    MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
    gender = 'None'
    age = (0,0)
    total_faces = 0
    try:
        #Get Faces
        ret, image = vidObj.read() 
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
        faces = faceCascade.detectMultiScale(
            gray,
            scaleFactor=1.3,
            minNeighbors=3,
            minSize=(30, 30)
        )
        total_faces = len(faces)
        for (x, y, w, h )in faces:
            cv2.rectangle(image, (x, y), (x+w, y+h), (255, 255, 0), 2)
            #Get Face 
            face_img = image[y:y+h, h:h+w].copy()
            blob = cv2.dnn.blobFromImage(face_img, 1, (227, 227), MODEL_MEAN_VALUES, swapRB=False)

            #Predict Age
            age_net.setInput(blob)
            age_preds = age_net.forward()
            age = age_list[age_preds[0].argmax()]

            #Predict Gender
            gender_net.setInput(blob)
            gender_preds = gender_net.forward()
            gender = gender_list[gender_preds[0].argmax()]
    except Exception: pass
        
    return total_faces, age, gender

# %%
#Trial
video_path = '/mnt/disks/user/project/Dataset/FaceSwap/videos/001_870_Deepfakes_c23.mp4'
vidObj = cv2.VideoCapture(video_path)
face,age,gender = object_detection(vidObj)
print('Face '+str(face))
print('Age '+ str(age))
print('Gender '+gender)
# Out:
# Face 1
# Age (25, 32)
# Gender Male

# %%
for video in final_dir:
    path = os.path.join(video+'videos/*.mp4')
    files = glob.glob(path, recursive = True) 
    for file in files:
        append_dataframe(file)
    print('Dataframe ready')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-6892db31404c> in <module>()
#       3     files = glob.glob(path, recursive = True)
#       4     for file in files:
# ----> 5         append_dataframe(file)
#       6     print('Dataframe ready')
#
# <ipython-input-4-a963a2fac7de> in append_dataframe(videopath)
#      13     vid_format = videopath.split('.')[1]
#      14     manipulation = videopath.split('/')[-3]
# ---> 15     face,age_val,gender = object_detection(vidObj)
#      16     global videos
#      17     videos = videos.append({'vid_path' : videopath,
#
# <ipython-input-5-2de9a92e36c2> in object_detection(vidObj)
#      20             scaleFactor=1.3,
#      21             minNeighbors=3,
# ---> 22             minSize=(30, 30)
#      23         )
#      24         total_faces = len(faces)
#
# KeyboardInterrupt:

# %%
len(videos)

# %%
videos.to_csv('Video_Dataset.csv')

# %% [markdown]
# ## Data Cleaning
# 1. Deleting Videos with 0 duration returned
# 2. Deleting Videos with No faces found

# %%
videos = pd.read_csv('Video_Dataset.csv')

# %%
print(videos.loc[videos.duration>50].vid_path)
# Out:
# 15      /mnt/disks/user/project/Dataset/FaceSwap/video...
# 89      /mnt/disks/user/project/Dataset/FaceSwap/video...
# 117     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 127     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 129     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 136     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 138     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 180     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 190     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 287     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 300     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 305     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 323     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 360     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 364     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 425     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 482     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 503     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 527     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 548     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 564     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 629     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 644     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 658     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 661     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 665     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 677     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 695     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 741     /mnt/disks/user/project/Dataset/FaceSwap/video...
# 751     /mnt/disks/user/project/Dataset/FaceSwap/video...
#                               ...
# 2065    /mnt/disks/user/project/Dataset/original/video...
# 2070    /mnt/disks/user/project/Dataset/original/video...
# 2098    /mnt/disks/user/project/Dataset/original/video...
# 2112    /mnt/disks/user/project/Dataset/original/video...
# 2132    /mnt/disks/user/project/Dataset/original/video...
# 2137    /mnt/disks/user/project/Dataset/original/video...
# 2157    /mnt/disks/user/project/Dataset/original/video...
# 2160    /mnt/disks/user/project/Dataset/original/video...
# 2206    /mnt/disks/user/project/Dataset/original/video...
# 2217    /mnt/disks/user/project/Dataset/original/video...
# 2232    /mnt/disks/user/project/Dataset/original/video...
# 2269    /mnt/disks/user/project/Dataset/original/video...
# 2311    /mnt/disks/user/project/Dataset/original/video...
# 2321    /mnt/disks/user/project/Dataset/original/video...
# 2345    /mnt/disks/user/project/Dataset/original/video...
# 2347    /mnt/disks/user/project/Dataset/original/video...
# 2441    /mnt/disks/user/project/Dataset/original/video...
# 2542    /mnt/disks/user/project/Dataset/original/video...
# 2698    /mnt/disks/user/project/Dataset/original/video...
# 2699    /mnt/disks/user/project/Dataset/original/video...
# 2757    /mnt/disks/user/project/Dataset/original/video...
# 2791    /mnt/disks/user/project/Dataset/original/video...
# 2800    /mnt/disks/user/project/Dataset/original/video...
# 2824    /mnt/disks/user/project/Dataset/original/video...
# 2851    /mnt/disks/user/project/Dataset/original/video...
# 2867    /mnt/disks/user/project/Dataset/original/video...
# 2879    /mnt/disks/user/project/Dataset/original/video...
# 2885    /mnt/disks/user/project/Dataset/original/video...
# 2888    /mnt/disks/user/project/Dataset/original/video...
# 2917    /mnt/disks/user/project/Dataset/original/video...
# Name: vid_path, Length: 92, dtype: object

# %%
videos.dtypes
# Out:
# Unnamed: 0             int64
# vid_path              object
# fps                  float64
# frame_count            int64
# duration             float64
# height               float64
# width                float64
# format                object
# faces                  int64
# gender                object
# age                   object
# manipulation_type     object
# dtype: object

# %%
videos.loc[:,['faces','frame_count']] = videos.loc[:,['faces','frame_count']].astype(int)

# %%
videos.frame_count.describe()
# Out:
# count    2982.000000
# mean      566.469148
# std       271.409651
# min        29.000000
# 25%       358.250000
# 50%       481.000000
# 75%       695.000000
# max      1814.000000
# Name: frame_count, dtype: float64

# %%
videos.dtypes
# Out:
# Unnamed: 0             int64
# vid_path              object
# fps                  float64
# frame_count            int64
# duration             float64
# height               float64
# width                float64
# format                object
# faces                  int64
# gender                object
# age                   object
# manipulation_type     object
# dtype: object

# %%
videos.head()
# Out:
#    Unnamed: 0                                           vid_path   fps  \
# 0           0  /mnt/disks/user/project/Dataset/FaceSwap/video...  25.0
# 1           1  /mnt/disks/user/project/Dataset/FaceSwap/video...  24.0
# 2           2  /mnt/disks/user/project/Dataset/FaceSwap/video...  25.0
# 3           3  /mnt/disks/user/project/Dataset/FaceSwap/video...  24.0
# 4           4  /mnt/disks/user/project/Dataset/FaceSwap/video...  30.0
#
#    frame_count   duration  height   width format  faces  gender       age  \
# 0          554  22.160000   480.0   656.0    mp4      1  Female    (4, 6)
# 1         1198  49.916667  1080.0  1920.0    mp4      2  Female  (48, 53)
# 2          505  20.200000   480.0   600.0    mp4      1    Male  (25, 32)
# 3          217   9.041667  1080.0  1920.0    mp4      1    Male    (4, 6)
# 4          314  10.466667   720.0  1280.0    mp4      1  Female  (15, 20)
#
#   manipulation_type
# 0          FaceSwap
# 1          FaceSwap
# 2          FaceSwap
# 3          FaceSwap
# 4          FaceSwap

# %%
floats = videos.select_dtypes('float')
floats.describe()
# Out:
#                fps     duration       height        width
# count  2982.000000  2982.000000  2982.000000  2982.000000
# mean     26.651241    21.873553   751.346747  1262.424547
# std       3.708666    11.567288   260.643695   540.133015
# min      15.000000     1.208333   480.000000   256.000000
# 25%      24.000000    13.360000   480.000000   640.000000
# 50%      25.000000    17.900000   720.000000  1280.000000
# 75%      30.000000    27.618750  1080.000000  1920.000000
# max      60.000000    72.560000  1080.000000  1920.000000

# %%
vals = videos.select_dtypes(['float','int'])
vals = vals[['fps','frame_count','duration']]
vals.describe()
# Out:
#                fps  frame_count     duration
# count  2982.000000  2982.000000  2982.000000
# mean     26.651241   566.469148    21.873553
# std       3.708666   271.409651    11.567288
# min      15.000000    29.000000     1.208333
# 25%      24.000000   358.250000    13.360000
# 50%      25.000000   481.000000    17.900000
# 75%      30.000000   695.000000    27.618750
# max      60.000000  1814.000000    72.560000

# %%
videos.faces.describe()
# Out:
# count    2982.000000
# mean        1.192488
# std         0.709714
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         7.000000
# Name: faces, dtype: float64

# %%
videos.isin([0,'None',(0,0)]).sum()
# Out:
# Unnamed: 0             1
# vid_path               0
# fps                    0
# frame_count            0
# duration               0
# height                 0
# width                  0
# format                 0
# faces                228
# gender               228
# age                    0
# manipulation_type      0
# dtype: int64

# %% [markdown]
# **NOTE**
# 1. It appears that same set of videos are returning 0 for fps,frame count, duration, height and width therefore can simply use one of the columns to extract null videos
# 2. Similarly - when faces are no recognised the gender is certainly not recognised
# 3. The age of (0,0) appears like is not considered in the count

# %%
#selecting rows with 0 values for duration/faces = 0, age = (0,0)
empty_files = videos.loc[(videos['duration'] == 0) | (videos['faces'] == 0)]
len(empty_files)
# Out:
# 228

# %%
empty = videos.loc[(videos['duration'] == 0) | (videos['faces'] == 0)]
len(empty)
# Out:
# 228

# %%
empty_files.vid_path.iloc[2]
# Out:
# '/mnt/disks/user/project/Dataset/FaceSwap/videos/07_21__secret_conversation__MKU99DVX_DeepFakeDetection_c23.mp4'

# %%
cap = cv2.VideoCapture(empty_files.vid_path.iloc[200])
cap.set(1,2); # Where frame_no is the frame you want
ret, frame = cap.read() # Read the frame
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Largely, we are unable to effectively crop/extract faces from the DeepFakeDetection set of videos

# %% [markdown]
# **NOTE**
#
# While in 20 instances, the videos appears to exist and has duration values, we would delete the videos. This is because face cropping is one of the important pre-processing steps and these videos would prove to be irrelevant in that case if the face is not recognised

# %%
for index, row in empty_files.iterrows():
    os.remove(row.vid_path)
    print(row.vid_path, 'has been removed')
# Out:
# /mnt/disks/user/project/Dataset/FaceSwap/videos/03_04__kitchen_pan__T04P6ELC_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/842_714_FaceSwap_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/07_21__secret_conversation__MKU99DVX_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/857_909_FaceSwap_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/14_01__hugging_happy__0S0NS5C6_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/09_01__outside_talking_pan_laughing__SJZRV69J_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_01__outside_talking_pan_laughing__9OM3VE0Y_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/20_09__outside_talking_pan_laughing__O5X0AWR9_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/05_16__outside_talking_pan_laughing__053HPS1G_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/27_26__kitchen_pan__IE9N0ZI9_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/18_06__outside_talking_pan_laughing__OWJY9LQU_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/04_15__outside_talking_pan_laughing__46TJ9IOJ_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/25_21__walking_outside_cafe_disgusted__2R46UX3R_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/04_12__kitchen_pan__B6YJ9IW1_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/279_298_Deepfakes_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/24_22__kitchen_pan__XL557XC6_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/18_06__kitchen_pan__5HNHMK6G_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/22_23__secret_conversation__J8JK3NBV_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_01__kitchen_pan__18HYCC8C_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/20_09__kitchen_pan__HG1S0KHA_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/28_16__secret_conversation__ZA8XJIE9_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_01__kitchen_pan__WIZ7GKOD_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/23_19__walking_outside_cafe_disgusted__D1K19NUP_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/16_05__outside_talking_pan_laughing__053HPS1G_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_01__secret_conversation__FCNL2OVP_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/15_03__outside_talking_pan_laughing__AIOM1U5V_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/14_02__outside_talking_pan_laughing__3IUBEKCT_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/03_04__outside_talking_pan_laughing__T04P6ELC_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/23_19__outside_talking_pan_laughing__H4SUVFTL_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/21_14__kitchen_still__IRKML4J0_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/02_01__secret_conversation__YVGY8LOK_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/04_13__secret_conversation__00T3UYOR_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/20_09__outside_talking_pan_laughing__MKEWB4SM_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_21__secret_conversation__T7DK03O1_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/854_747_FaceSwap_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/03_06__kitchen_pan__1IXGY2FK_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/08_28__outside_talking_pan_laughing__HIOU8Z8I_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/15_03__kitchen_pan__5C1OMK8W_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/22_19__outside_talking_pan_laughing__VK6BF5NV_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/14_02__walking_outside_cafe_disgusted__3IUBEKCT_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/28_16__kitchen_pan__X5FNCYON_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/08_28__kitchen_pan__6HFK6PB4_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/24_22__outside_talking_pan_laughing__XL557XC6_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/720_672_FaceSwap_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_21__walking_outside_cafe_disgusted__T7DK03O1_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_21__secret_conversation__1EAA3MPV_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_04__outside_talking_pan_laughing__JRQWOV1G_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/04_15__outside_talking_pan_laughing__7NW4Z6WZ_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/25_21__outside_talking_pan_laughing__2R46UX3R_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/826_833_FaceSwap_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/660_634_FaceSwap_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/26_25__outside_talking_pan_laughing__157Z8P8P_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/08_28__outside_talking_pan_laughing__8BC35RFU_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/22_23__kitchen_pan__W9MT3Q5K_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/18_06__outside_talking_pan_laughing__DEA1TCLN_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/22_23__outside_talking_pan_laughing__TU7RHG0S_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/26_25__outside_talking_pan_laughing__GJT740J9_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_01__outside_talking_pan_laughing__WIZ7GKOD_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/12_18__outside_talking_pan_laughing__IKH1LBBY_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/03_06__kitchen_pan__2XWC5JED_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/03_06__secret_conversation__1IXGY2FK_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/22_23__outside_talking_pan_laughing__J671JKCH_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/732_691_FaceSwap_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/07_20__outside_talking_pan_laughing__KV6Q7D6C_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/607_683_FaceSwap_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_03__outside_talking_pan_laughing__P08VGHTA_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/23_19__secret_conversation__H4SUVFTL_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/25_21__outside_talking_pan_laughing__NFBISHIN_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/28_16__secret_conversation__X5FNCYON_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/21_14__talking_angry_couch__N0WM4GSV_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/07_20__outside_talking_pan_laughing__5VT4USF9_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/19_10__outside_talking_pan_laughing__FFXB67PI_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_01__outside_talking_pan_laughing__UQ0BOBNO_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/22_23__kitchen_pan__TU7RHG0S_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/07_21__secret_conversation__CRGVSDBI_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/152_149_Deepfakes_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/08_28__kitchen_pan__LVT0XNQG_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/22_23__secret_conversation__10R2HRAU_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/28_16__secret_conversation__R1QD0XDQ_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/11_21__kitchen_pan__T7DK03O1_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/852_834_FaceSwap_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/01_02__secret_conversation__YVGY8LOK_DeepFakeDetection_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/FaceSwap/videos/15_03__kitchen_pan__DG8ITQO3_DeepFakeDetection_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/Reenactment/videos/324_356_Face2Face_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/Reenactment/videos/854_747_NeuralTextures_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/Reenactment/videos/521_517_Face2Face_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/Reenactment/videos/441_439_Face2Face_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/Reenactment/videos/347_314_Face2Face_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/Reenactment/videos/414_385_Face2Face_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/10__talking_angry_couch_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/196_youtube_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/13__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/14__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/28__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/04__secret_conversation_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/05__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/09__kitchen_pan_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/23__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/28__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/18__walking_outside_cafe_disgusted_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/21__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/13__secret_conversation_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/16__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/17__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/16__walking_outside_cafe_disgusted_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/763_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/17__hugging_happy_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/19__walking_outside_cafe_disgusted_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/26__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/13__talking_angry_couch_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/28__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/07__secret_conversation_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/09__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/14__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/27__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/14__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/646_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/20__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/24__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/26__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/14__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/05__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/25__walking_down_street_outside_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/15__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/15__walking_outside_cafe_disgusted_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/06__kitchen_pan_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/03__secret_conversation_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/12__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/06__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/25__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/25__secret_conversation_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/660_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/08__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/17__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/24__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/02__walking_outside_cafe_disgusted_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/02__secret_conversation_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/521_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/842_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/18__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/18__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/17__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/09__exit_phone_room_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/12__secret_conversation_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/26__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/414_youtube_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/07__kitchen_pan_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/22__secret_conversation_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/14__walking_outside_cafe_disgusted_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/13__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/171_youtube_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/01__secret_conversation_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/25__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/02__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/26__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/13__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/28__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/12__exit_phone_room_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/24__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/25__outside_talking_still_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/720_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/13__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/12__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/07__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/20__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/10__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/11__walking_outside_cafe_disgusted_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/22__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/19__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/23__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/02__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/27__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/05__exit_phone_room_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/06__hugging_happy_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/013_youtube_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/09__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/15__outside_talking_still_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/20__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/12__hugging_happy_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/15__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/274_youtube_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/626_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/25__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/18__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/24__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/20__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/10__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/21__kitchen_pan_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/16__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/03__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/03__kitchen_pan_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/01__exit_phone_room_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/01__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/08__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/16__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/11__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/854_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/04__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/808_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/11__kitchen_pan_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/03__outside_talking_pan_laughing_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/04__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/18__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/08__walking_outside_cafe_disgusted_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/19__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/05__walking_outside_cafe_disgusted_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/22__outside_talking_pan_laughing_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/27__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/07__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/12__walking_outside_cafe_disgusted_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/21__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/25__walking_outside_cafe_disgusted_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/16__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/21__walking_outside_cafe_disgusted_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/06__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/19__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/28__secret_conversation_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/04__kitchen_pan_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/905_youtube_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/23__exit_phone_room_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/21__talking_angry_couch_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/23__secret_conversation_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/21__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/06__exit_phone_room_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/19__secret_conversation_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/22__walk_down_hall_angry_actors_c40.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/11__walk_down_hall_angry_actors_c23.mp4 has been removed
# /mnt/disks/user/project/Dataset/original/videos/636_youtube_c40.mp4 has been removed

# %%
videos.format.value_counts()
# Out:
# mp4    2982
# Name: format, dtype: int64

# %% [markdown]
# All video files are in mp4 format. The column is practically redundant

# %% [markdown]
# ## EDA Analysis
# 1. Perform Univariate analysis on each feature and returning relevant tables.
# 2. Find relationships between variables if any

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plot = vals
fig, axs = plt.subplots(1,3, figsize=(30,10))
ax_iter = iter(axs.flat)
for i in range(len(vals.columns)):
    ax = next(ax_iter)
    sns.boxplot(x=plot.iloc[:,i], ax=ax)
axs[-1].axis('on')
plt.show()

# %% [markdown]
# For all continous variables make a distplot

# %%
plot = floats
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax_iter = iter(axs.flat)
for i in range(len(floats.columns)):
    ax = next(ax_iter)
    sns.boxplot(x=plot.iloc[:,i], ax=ax)
axs[-1, -1].axis('on')
plt.show()

# %%
sns.distplot(floats.duration)
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(floats.height)
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(videos.height)
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(floats.width)
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
age_order = ('(0, 2)', '(4, 6)', '(8, 12)', '(15, 20)', '(25, 32)', '(38, 43)', '(48, 53)', '(60, 100)')

# %%
sns.countplot(x = videos.age, palette="Set3", order=age_order)

# %%
sns.countplot(x = videos.faces, palette="Set3")

# %% [markdown]
# For categorical variables using Pie Charts to gauge the distribution

# %%
mani_labels = videos.manipulation_type.unique()

# %%
mani_values = videos.manipulation_type.value_counts()

# %%
manipulation = mani_values.to_dict()
print(manipulation)
# Out:
# {'FaceSwap': 1422, 'original': 1363, 'Reenactment': 600}

# %%
fig1, ax1 = plt.subplots()
ax1.pie(manipulation.values(), labels=manipulation.keys(),autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
gender_values = videos.gender.value_counts()

# %%
gender = gender_values.to_dict()
print(gender)
# Out:
# {'Female': 2142, 'Male': 1015, 'None': 228}

# %%
fig1, ax1 = plt.subplots()
ax1.pie(gender.values(), labels=gender.keys(),autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# **Understanding the Face better**

# %%
videos.faces.value_counts()
# Out:
# 1    2468
# 2     519
# 0     228
# 3     123
# 4      36
# 5       5
# 7       4
# 6       2
# Name: faces, dtype: int64

# %%
extra_faces = videos.loc[videos['faces'] > 1]

# %%
print(len(extra_faces.vid_path))
# Out:
# 595

# %%
random_index = random.randint(0, len(extra_faces))
videos_path = extra_faces.iloc[random_index].vid_path

# %%
cap = cv2.VideoCapture(videos_path)
cap.set(1,2); # Where frame_no is the frame you want
ret, frame = cap.read() # Read the frame
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30)
)
print("[INFO] Found {0} Faces!".format(len(faces)))
for (x, y, w, h) in faces:
    #print(faces)
    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
    roi_color = frame[y-20:y + h + 20, x-20:x + w + 20]
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(roi_color, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [INFO] Found 2 Faces!

# %%
import random
from skimage import io
import cv2

# %%
rand_index = random.randint(0, len(extra_faces))
video_path = extra_faces.iloc[rand_index].vid_path

# %%
cap = cv2.VideoCapture(video_path)
cap.set(1,2); # Where frame_no is the frame you want
ret, frame = cap.read() # Read the frame
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30)
)
print("[INFO] Found {0} Faces!".format(len(faces)))
print('Faces, ',str(faces))
#faces = np.delete(faces,1,0)
print('Final Face',str(faces))
for (x, y, w, h) in faces:
    print(faces)
    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
    roi_color = frame[y-20:y + h + 20, x-20:x + w + 20]
plt.imshow(cv2.cvtColor(roi_color, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [INFO] Found 2 Faces!
# Faces,  [[156 101  53  53]
#  [458 246 195 195]]
# Final Face [[156 101  53  53]
#  [458 246 195 195]]
# [[156 101  53  53]
#  [458 246 195 195]]
# [[156 101  53  53]
#  [458 246 195 195]]
